# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/indicators/un_indicators.csv')
# Out:
# C:\Users\graft\AppData\Local\Temp\ipykernel_131540\3952853818.py:1: DtypeWarning: Columns (2,3,4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/indicators/un_indicators.csv')

# %%
df.head(15)
# Out:
#     SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 1         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 2         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 3         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 4         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 5         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 6         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 7         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 8         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 9         NaN   5507   NaN       NaN       NaN        NaN        NaN
# 10        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 11        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 12        NaN   5507   NaN       NaN       NaN        NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['SortOrder', 'LocID', 'Notes', 'ISO3_code', 'ISO2_code', 'SDMX_code',
#        'LocTypeID', 'LocTypeName', 'ParentID', 'Location', 'VarID', 'Variant',
#        'Time', 'TPopulation1Jan', 'TPopulation1July', 'TPopulationMale1July',
#        'TPopulationFemale1July', 'PopDensity', 'PopSexRatio', 'MedianAgePop',
#        'NatChange', 'NatChangeRT', 'PopChange', 'PopGrowthRate',
#        'DoublingTime', 'Births', 'Births1519', 'CBR', 'TFR', 'NRR', 'MAC',
#        'SRB', 'Deaths', 'DeathsMale', 'DeathsFemale', 'CDR', 'LEx', 'LExMale',
#        'LExFemale', 'LE15', 'LE15Male', 'LE15Female', 'LE65', 'LE65Male',
#        'LE65Female', 'LE80', 'LE80Male', 'LE80Female', 'InfantDeaths', 'IMR',
#        'LBsurvivingAge1', 'Under5Deaths', 'Q5', 'Q0040', 'Q0040Male',
#        'Q0040Female', 'Q0060', 'Q0060Male', 'Q0060Female', 'Q1550',
#        'Q1550Male', 'Q1550Female', 'Q1560', 'Q1560Male', 'Q1560Female',
#        'NetMigrations', 'CNMR'],
#       dtype='object')

# %%
df_splice = df[['Time', 'Location', 'ISO3_code', 'Births', 'CBR', 'TFR', 'NRR', 'PopGrowthRate', 'TPopulation1Jan']]

# %%
df_splice
# Out:
#        Time                           Location ISO3_code    Births     CBR  \
# 0      1950  ADB region: Central and West Asia       NaN  2933.594  42.385
# 1      1951  ADB region: Central and West Asia       NaN  3012.920  42.626
# 2      1952  ADB region: Central and West Asia       NaN  3099.971  42.913
# 3      1953  ADB region: Central and West Asia       NaN  3193.546  43.228
# 4      1954  ADB region: Central and West Asia       NaN  3288.272  43.495
# ...     ...                                ...       ...       ...     ...
# 84355  2097          Wallis and Futuna Islands       WLF     0.046   6.458
# 84356  2098          Wallis and Futuna Islands       WLF     0.046   6.542
# 84357  2099          Wallis and Futuna Islands       WLF     0.046   6.658
# 84358  2100          Wallis and Futuna Islands       WLF     0.047   6.771
# 84359  2101          Wallis and Futuna Islands       WLF       NaN     NaN
#
#           TFR     NRR  PopGrowthRate  TPopulation1Jan
# ...

# %%
df2 = df2[['Alpha-3 code', 'Latitude (average)', 'Longitude (average)']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df2 = df2[['Alpha-3 code', 'Latitude (average)', 'Longitude (average)']]
#
# NameError: name 'df2' is not defined

# %%
df2 = df2.rename(columns = {'Alpha-3 code': 'ISO3_code', 'Latitude (average)': 'Latitude', 'Longitude (average)': 'Longitude'})

# %%
df2['ISO3_code']=df2['ISO3_code'].str.split('"', expand=True).drop(columns=[0,2])

# %%
df2['Latitude']=df2['Latitude'].str.split('"', expand=True).drop(columns=[0,2])

# %%
df2['Longitude']=df2['Longitude'].str.split('"', expand=True).drop(columns=[0,2])

# %%
df2

# %%
df3 = pd.merge(df_splice, df2, left_on='ISO3_code', right_on='ISO3_code', how = 'left')

# %%
df3

# %%
region_world = df3.loc[df3['ISO3_code'].isna()]

# %%
world = df3.loc[df3['Location'] == 'World']

# %%
country = df3.loc[~df3['ISO3_code'].isna()]

# %%
region=region_world.loc[~region_world['Location'].isin(world)]

# %%
niger = country.loc[country['Location']=='Niger']

# %%
china = country.loc[country['Location']=='China']

# %%
plt.figure(figsize=(8, 6))


plt.plot(china['Time'], china['PopGrowthRate'])

# %%
df=pd.read_csv('../data/maps/synoptic_continent.csv')

# %%
df=df.loc[df['Religion']!='General Population']
df

# %%
df.to_csv('synoptic_continent.csv',index=False)

# %%
df=pd.read_csv('../data/ras_project/LX/lx07.csv')

# %%
df

# %%
df=df[['COUNTRY','LX07X2010']]

# %%
df

# %%
df.loc[df['LX07X2010']==1]

# %%
Asia 1970-2010

# %%
((.21-2.51)/2.51)*100
